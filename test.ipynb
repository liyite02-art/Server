# %%
import sys
import logging
from pathlib import Path

# 配置项目根目录
ROOT = Path("/root/autodl-tmp/Strategy")
sys.path.insert(0, str(ROOT.parent))

logging.basicConfig(level=logging.INFO, force=True)
for name in ("Strategy", "Strategy.model", "Strategy.backtest"):
    logging.getLogger(name).setLevel(logging.INFO)

from Strategy import config

# %%
from Strategy.label.label_generator import generate_and_save_open930_1000_label

# 需 Daily_data: CLOSE_PRICE / PRE_CLOSE_PRICE / LIMIT_UP_PRICE / LIMIT_DOWN_PRICE (.pkl)
# 可选: start_date=20210104, end_date=20251231 缩小范围以加快调试
# 若无涨跌停价文件仅做调试: generate_and_save_open930_1000_label(use_limit_price_tables=False)
open930_1000_label_path = generate_and_save_open930_1000_label()
print(f"[OPEN930_1000] Label 已生成: {open930_1000_label_path}")

# 其他标签示例 (分钟 open 持有期):
# from Strategy.label.label_generator import generate_and_save_open0935_1000_label
# generate_and_save_open0935_1000_label(save_price_tables=True)
# Out:
# INFO:Strategy.label.label_generator:开始计算分钟 open 宽表 time=930, 共 1261 个交易日
# Open@930:   0%|          | 0/1261 [00:00<?, ?day/s]
# INFO:Strategy.label.label_generator:open 宽表计算完成 time=930, shape=(1261, 0)
# INFO:Strategy.label.label_generator:开始计算分钟 open 宽表 time=1000, 共 1261 个交易日
# Open@1000:   0%|          | 0/1261 [00:00<?, ?day/s]
# INFO:Strategy.label.label_generator:open 宽表计算完成 time=1000, shape=(1261, 5380)
# INFO:Strategy.label.label_generator:OPEN930_1000 Label 除权调整已应用 (CLOSE / PRE_CLOSE), 共 0 支股票列对齐
# INFO:Strategy.label.label_generator:OPEN930_1000 涨跌停剔除: buy涨停=0 | T+1 10:00跌停=0
# INFO:Strategy.label.label_generator:OPEN930_1000 Label 已保存: /root/autodl-tmp/Strategy/outputs/labels/LABEL_OPEN930_1000.fea, shape=(1261, 0)
# INFO:Strategy.label.label_generator:OPEN930_1000 买入价格 mask 已保存: /root/autodl-tmp/Strategy/outputs/labels/OPEN930_1000.fea
# [OPEN930_1000] Label 已生成: /root/autodl-tmp/Strategy/outputs/labels/LABEL_OPEN930_1000.fea

# %%
import pandas as pd
df = pd.read_feather(r'/root/autodl-tmp/Strategy/outputs/labels/OPEN930_1000.fea')
df
# Out:
#      TRADE_DATE
# 0    2021-01-04
# 1    2021-01-05
# 2    2021-01-06
# 3    2021-01-07
# 4    2021-01-08
# ...         ...
# 1256 2026-03-16
# 1257 2026-03-17
# 1258 2026-03-18
# 1259 2026-03-19
# 1260 2026-03-20
#
# [1261 rows x 1 columns]
