# %%
import pandas as pd
df = pd.read_feather(r'/root/autodl-tmp/Strategy/outputs/labels/LABEL_TWAP_1430_1457.fea')
df
# Out:
#      TRADE_DATE    000001    000002    000004    000005    000006    000007  \
# 0    2021-01-04 -0.023894  0.005246 -0.008600 -0.013780 -0.016648 -0.099852
# 1    2021-01-05  0.067355  0.027531 -0.035796 -0.029242 -0.010237 -0.099918
# 2    2021-01-06  0.024298  0.002059 -0.054087 -0.013800 -0.025194 -0.100394
# 3    2021-01-07 -0.004104  0.021221  0.008778 -0.001806 -0.001360 -0.100656
# 4    2021-01-08  0.029910  0.018158 -0.044794 -0.030901 -0.014370 -0.087070
# ...         ...       ...       ...       ...       ...       ...       ...
# 1256 2026-03-16  0.010720  0.005749 -0.049573       NaN -0.008861  0.038560
# 1257 2026-03-17 -0.007405 -0.010747 -0.050360       NaN  0.017724  0.016537
# 1258 2026-03-18 -0.007265 -0.027660  0.048295       NaN -0.017454 -0.032079
# 1259 2026-03-19 -0.009451 -0.036133 -0.046264       NaN -0.026468 -0.023262
# 1260 2026-03-20       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
df.columns
# Out:
# Index(['TRADE_DATE', '000001', '000002', '000004', '000005', '000006',
#        '000007', '000008', '000009', '000010',
#        ...
#        '688800', '688802', '688805', '688807', '688809', '688816', '688818',
#        '688819', '688981', '689009'],
#       dtype='object', length=5381)

# %%
import pandas as pd
df1 = pd.read_feather(r'/root/autodl-tmp/Strategy/outputs/factors/doji.fea')
df1
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[4], line 2
#       1 import pandas as pd
# ----> 2 df1 = pd.read_feather(r'/root/autodl-tmp/Strategy/outputs/factors/doji.fea')
#       3 df1
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/io/feather_format.py:123, in read_feather(path, columns, use_threads, storage_options, dtype_backend)
#     119 with get_handle(
#     120     path, "rb", storage_options=storage_options, is_text=False
#     121 ) as handles:
#     122     if dtype_backend is lib.no_default and not using_string_dtype():
# --> 123         return feather.read_feather(
#     124             handles.handle, columns=columns, use_threads=bool(use_threads)
#     125         )
#     127     pa_table = feather.read_table(
#     128         handles.handle, columns=columns, use_threads=bool(use_threads)
#     129     )
# ...
