# %%
from gp_framework.api import fit_gp_formula, eva_gp_performance

# %%
import os

# %%
res = eva_gp_performance("test_0530_119", plot_data=True)
# Out:
#                count      mean       std  min  25%  50%   75%  max
# abs_ic_label5    7.0  1.685714  0.186445  1.5  1.5  1.7  1.85  1.9

# %%
res['formula_df']
